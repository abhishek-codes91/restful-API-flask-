# %% [markdown]
# # restful api & flask
#  1.Restful API & Flask?
#  >-A RESTful API is a way for two systems (like app and server) to talk to each other using the web.
#
#  - t uses HTTP methods like:
#
# - ET → get data
#
#  - OST → add data
#
#  - pUT/PATCH → update data
#
#  - dELETE → remove data
#
#  - data is usually shared in JSON format.
#
#  - Each piece of data is called a resource (like user, book, order).
#
#  - REST is stateless, meaning each request works on its own (server doesn’t remember previous requests).
#
#  2.Explain the concept of API specification?
#  >-API Specification (API Spec)
#
# - an API specification is like a blueprint or rulebook for how an API works.
#
# - It tells developers what the API can do, how to use it, and what to expect in return.
#
#    1.Endpoints (URLs)
#
# - Example: /users, /orders/5
#
#  - Shows where to send requests.
#
#    2.Methods
#
#  - Explains which HTTP methods you can use: GET, POST, PUT, DELETE.
#
#    3.Parameters
#
#    - Inputs you can send with requests (like ?id=10 or { "name": "John" }).
#
#     4.Responses
#
#  - What the API gives back (usually in JSON), including success and error messages.
#
#     5.Authentication Rules
#
#  - How to prove who you are (like API keys, tokens, etc.).
#
#  3.What is Flask, and why is it popular for building APIs?
#
#  >-Flask is a Python web framework (a set of tools) used to build web applications and APIs.
#
# - It’s called a micro-framework because it’s lightweight and doesn’t force you to use a lot of built-in features.
#
#  - You just install it and quickly start making routes (endpoints) for your API.
#
#  4.What is routing in Flask?
#  >-Routing in Flask means deciding which function should run when a user visits a specific URL (endpoint).
#
#  - In simple words: you connect a URL to a Python function
#
#  5.How do you create a simple Flask application?
#  >-Install Flask → pip install flask
#
# >-Import Flask in Python → from flask import Flask
#
# >-Create app → app = Flask(__name__)
#
# >-Define a route → @app.route("/") with a function
#
# >-Run the app → app.run(debug=True)
#
#  6.What are HTTP methods used in RESTful APIs?
#  >-GET → Retrieve data (read).
#
#  - Example: GET /users → get all users.
#
#  - POST → Create new data.
#
# - Example: POST /users → add a new user.
#
# - PUT → Update/replace existing data.
#
#  - Example: PUT /users/1 → replace user with ID 1.
#
#  - PATCH → Partially update existing data.
#
#    - Example: PATCH /users/1 → update only some fields of user 1.
#
#  - DELETE → Remove data.
#
#  - Example: DELETE /users/1 → delete user with ID 1.
#
#  7.What is the purpose of the @app.route() decorator in Flask?
#  >-@app.route() in Flask is a decorator used to map a URL (route) to a function.
#
#  - It tells Flask: “When someone visits this URL, run this function.”
#
#  - -Example:
#
#    @app.route("/hello")
#    def hello():
#     return "Hello, World!"
#
#
#  - Visiting /hello → runs hello() function.
#
#  - You can define different routes for different pages or API endpoints.
#
#  - It makes routing easy and readable.
#
#  8.What is the difference between GET and POST HTTP methods?
#  >-GET
#
#  - Retrieve data from server
#
#  - Data sent in URL (query string)
#
#  - Visible in browser
#
#  - Can be cached
#
#    - Idempotent (repeating doesn’t change data)
#
# >-POST
#
#  - Send data to server (create/update)
#
# - Data sent in request body
#
#  - Not visible in URL
#
# - Not cached
#
#  - Not necessarily idempotent
#
#  9.How do you handle errors in Flask APIs?
#  >-Use abort() to raise HTTP errors (e.g., abort(404)).
#
#   - Use try-except blocks to catch exceptions.
#
# - Create custom error handlers with @app.errorhandler().
#
#  - Return JSON responses for errors.
#
#  - Use proper HTTP status codes (e.g., 404, 400, 500).
#
#  10.How do you connect Flask to a SQL database?
#  >-Install a database library (e.g., SQLite, MySQL, PostgreSQL).
#
#  - Install Flask SQLAlchemy → pip install flask_sqlalchemy.
#
#  - Import Flask and SQLAlchemy, configure database URI.
#
# - Define database models (tables) using classes.
#
#  - Create the database → db.create_all().
#
#  - Perform CRUD operations using db.session (add, query, update, delete).
#
#  11.What is the role of Flask-SQLAlchemy?
#  >-Integrates SQLAlchemy with Flask → makes database operations easier.
#
#  - Acts as an ORM (Object Relational Mapper) → lets you work with Python classes instead of raw SQL.
#
#  - Simplifies CRUD operations → create, read, update, delete records using Python code.
#
#  - Handles database connections automatically.
#
#  - Supports multiple databases (SQLite, MySQL, PostgreSQL, etc.) with minimal changes.
#
#  - Provides query methods like .query.all(), .query.filter_by().
#
#  12.What are Flask blueprints, and how are they useful?
#  >-Blueprints let you organize a Flask app into smaller, reusable modules.
#  - They help split routes, templates, and static files for better structure.
#
#  - Useful for large applications with many endpoints.
#
# - Can register the same blueprint multiple times with different URL prefixes.
#
#  - Makes code maintenance easier and promotes reusability.
#
#  13.What is the purpose of Flask's request object?
#  >-The request object contains all the data sent by the client to the server.
#
#  - It allows access to form data, query parameters, headers, cookies, and JSON.
#
#  - Helps in handling GET and POST requests.
#
#  - Provides methods like:
#
#  - request.args → query parameters (?id=1)
#
#  - request.form → form data
#
# - request.json → JSON payload
#
#  - request.headers → HTTP headers
#
#  - Enables processing user input inside route functions.
#
#  14.How do you create a RESTful API endpoint using Flask?
#  >-Import Flask, jsonify, and request.
#
# - Create a Flask app → app = Flask(__name__).
#
#  - Define a route with @app.route("/endpoint", methods=[...]).
#
#  - Write a function to handle the request.
#
#  - Return data as JSON using jsonify().
#
#  - Run the app → app.run(debug=True).
#
#  - (Optional) Use request to handle input data for POST/PUT/PATCH.
#
#  15.What is the purpose of Flask's jsonify() function?
#  >-Converts Python data (dict, list, etc.) into JSON format.
#
#  - Sets the Content-Type header to application/json automatically.
#
#  - Makes it easier to send API responses in a standard format.
#
#  - Handles serialization of data types that JSON supports.
#
#  - Ensures the response is compatible with RESTful APIs.
#
#   16.Explain Flask’s url_for() function?
#   >-Generates URLs for routes dynamically instead of hardcoding them.
#
#  - Takes the function name of a route as the first argument.
#
#  - Automatically handles URL changes if route paths are updated.
#
#  - Can pass parameters for dynamic routes:
#
#  - url_for('user_profile', username='abhishek')
#
#
#  - Commonly used in templates for links, forms, and static files.
#
#  - Helps avoid broken links and keeps the app maintainable.
#
#  17.How does Flask handle static files (CSS, JavaScript, etc.)?
#  >-Place static files in a folder named static.
#
#  - Access files using url_for('static', filename='file_path').
#
#  - Common static files: CSS, JS, images.
#
#  - Default folder structure:
#
#    /app.py
#
#    /static/
#
#     style.css
#
#     script.js
#
#    /templates/
#
#     index.html
#
#
#  - Can configure a custom static folder via static_folder in Flask().
#
#  18.What is an API specification, and how does it help in building a Flask API?
#  >-An API specification is a document or blueprint that defines how an API should behave.
#
#  - It lists endpoints, HTTP methods, request parameters, responses, and error codes.
#
#  - Helps developers understand how to interact with the API without guessing.
#
#  - Ensures consistency and standardization in API design.
#
#  - Guides Flask app development: defining routes, handling requests, and sending responses.
#
#  - Facilitates documentation, testing, and collaboration between frontend and backend teams.
#
#  19.What are HTTP status codes, and why are they important in a Flask API?
#  >-HTTP status codes are numeric codes sent by the server to indicate the result of a client’s request.
#
#  - Common categories:
#
#  - 1xx → Informational
#
#  - 2xx → Success (e.g., 200 OK)
#
#  - 3xx → Redirection
#
# - 4xx → Client errors (e.g., 404 Not Found)
#
#  - 5xx → Server errors (e.g., 500 Internal Server Error)
#
#  - They communicate the outcome of the API request to the client.
#
#  - Help clients handle responses properly (e.g., retry, show error, or continue).
#
# - Essential for RESTful API standards to make APIs predictable and reliable.
#
#  - In Flask, you can return status codes with responses:
#
#     return {"error": "Not found"}, 404
#
#  20.How do you handle POST requests in Flask?
#  >-Define a route with methods=["POST"] using @app.route().
#
#  - Use request object to get incoming data (request.json or request.form).
#
#  - Process or validate the received data.
#
#  - Return a response (usually JSON) with an appropriate status code.
#
#  - Optionally, handle errors using try-except or abort().
#
#  21.How would you secure a Flask API?
#  >-Use authentication
#
#  - API keys, tokens (e.g., JWT), or OAuth to verify users.
#
#  - Use HTTPS
#
#  - Encrypt data in transit with SSL/TLS.
#
#  - Validate input data
#
#  - Prevent SQL injection, XSS, and other attacks.
#
#  - Implement rate limiting
#
#  - Prevent abuse or DDoS attacks.
#
#  - Handle errors securely
#
#  - Don’t expose sensitive information in error messages.
#
# - Use CORS carefully
#
#  - Control which domains can access your API.
#
#  - Keep dependencies updated
#
#  - Avoid vulnerabilities in libraries and frameworks.
#
#  22.What is the significance of the Flask-RESTful extension?
#  >-Simplifies building RESTful APIs in Flask.
#
#  - Provides Resource classes to organize endpoints cleanly.
#
#  - Handles HTTP methods (GET, POST, PUT, DELETE) in a structured way.
#
#  - Supports automatic request parsing and validation.
#
#  - Makes response formatting and error handling easier.
#
#  - Integrates well with Flask extensions like Flask-SQLAlchemy.
#
#  23.What is the role of Flask’s session object?
#  >-Stores data for a specific user across multiple requests.
#
#  - Keeps information between page visits (like login status, user preferences).
#
#  - Data is stored on the client side (usually in a secure cookie).
#
#  - Requires a secret key for encryption: app.secret_key = "your_secret_key".
#
#  - Can be used like a dictionary:
#
#     session['username'] = 'Abhishek'
#
#
#  - Helps manage user-specific state in a stateless HTTP environment.

# %%
#practical question

# 1.How do you create a basic Flask application?
# Import Flask
from flask import Flask

# Create a Flask app
app = Flask(__name__)

# Define a route for the home page
@app.route("/")
def home():
    return "Hello, Flask! 🚀"

# Run the app
if __name__ == "__main__":
    app.run(debug=True)


#2.How do you serve static files like images or CSS in Flask?
<link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
<img src="{{ url_for('static', filename='logo.png') }}">

#3.How do you define different routes with different HTTP methods in Flask?
from flask import request

@app.route("/user", methods=["GET", "POST"])
def user():
    if request.method == "POST":
        return "POST request received"
    return "GET request received"

#4.How do you render HTML templates in Flask?
from flask import render_template

@app.route("/home")
def home_page():
    return render_template("index.html")

#5.How can you generate URLs for routes in Flask using url_for?
from flask import url_for

@app.route("/profile/<username>")
def profile(username):
    return f"User: {username}"

# In template
<a href="{{ url_for('profile', username='Abhishek') }}">Profile</a>

#6.How do you handle forms in Flask?
@app.route("/submit", methods=["GET", "POST"])
def submit():
    if request.method == "POST":
        name = request.form['name']
        return f"Hello, {name}"
    return render_template("form.html")

#7.How can you validate form data in Flask?
if not name:
   return "Name is required", 400

#8.How do you manage sessions in Flask?
from flask import session
app.secret_key = "secret123"

@app.route("/login")
def login():
    session['user'] = 'Abhishek'
    return "Logged in"

@app.route("/logout")
def logout():
    session.pop('user', None)
    return "Logged out"

#9.How do you redirect to a different route in Flask?
from flask import redirect, url_for

@app.route("/go-home")
def go_home():
    return redirect(url_for('home'))

#10.How do you handle errors in Flask (e.g., 404)?
@app.errorhandler(404)
def not_found(e):
    return "Page not found", 404

#11.How do you structure a Flask app using Blueprints?
from flask import Blueprint

auth = Blueprint('auth', __name__)

@auth.route("/login")
def login():
    return "Login Page"

# Register blueprint in main app
app.register_blueprint(auth, url_prefix="/auth")

#12.How do you define a custom Jinja filter in Flask?
@app.template_filter('reverse')
def reverse_filter(s):
    return s[::-1]

# In template: {{ "hello"|reverse }} → "olleh"

#13.How can you redirect with query parameters in Flask?
return redirect(url_for('search', q='Flask'))
# URL becomes /search?q=Flask

#14.How do you return JSON responses in Flask?
from flask import jsonify

@app.route("/api/users")
def api_users():
    return jsonify([{"id":1, "name":"Abhishek"}, {"id":2, "name":"Alice"}])

#15.How do you capture URL parameters in Flask?
@app.route("/user/<int:id>")
def get_user(id):
    return f"User ID: {id}"
